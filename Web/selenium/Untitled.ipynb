# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


from bs4 import BeautifulSoup
import requests


import csv

# #Abrir archivo
# archivo_de_publicaciones_por_provincias = open("Publicaciones_por_provincia_Galapagos.csv", "w",newline='' ,encoding='utf-8-SIG')
# archivo_de_publicaciones_por_perfil = open("Publicaciones_por_perfil_Galapagos.csv", "w",newline='' ,encoding='utf-8-SIG')
# encabezado1=["Provincia","Nombre de usuario","Lugar","Fecha","Hora","Descripcion"]
# salida= csv.writer(archivo_de_publicaciones_por_provincias,delimiter='|')
# salida.writerow(encabezado1)
# encabezado2=["Provincia","Nombre de usuario","Link"]
# salida1= csv.writer(archivo_de_publicaciones_por_perfil,delimiter='|')
# salida1.writerow(encabezado2)
#
# #entrar a la cuenta
#
username = "miathvill9029@gmail.com"
password = "miang9029"
url = "https://www.instagram.com/accounts/login/"
provincias= ["GALAPAGOS"]
#provincias=["ESMERALDAS","CARCHI","IMBABURA","GUAYAS","PICHINCHA","SANTO DOMINGO DE LOS TSACHILAS","MANABI","SANTA ELENA","LOS RIOS","COTOPAXI","TUNGURAHUA","BOLIVAR","CHIMBORAZO","CAÑAR","AZUAY",
# "EL ORO","LOJA","ZAMORA CHINCHIPE", "MORONA SANTIAGO","PASTAZA","ORELLANA","SUCUMBIOS","NAPO",
#"GALAPAGOS"]

def login(username, your_password):
    log_but = browser.find_element_by_class_name("_9GP1n   ")
    time.sleep(1)
    log_but.click()
    browser.implicitly_wait(1)

    usern = browser.find_element_by_name("username")

    usern.send_keys(username)

    passw = browser.find_element_by_name("password")

    passw.send_keys(your_password)

    passw.send_keys(Keys.ENTER)
    time.sleep(1)

def first_picture():
    try:
        pic = browser.find_element_by_class_name("_9AhH0")
        browser.implicitly_wait(1)
        return pic.click()
    except:
         return False

def next_picture():
    try:
        next = browser.find_element_by_xpath("//a[contains(text(),'Next')]")
        browser.implicitly_wait(1)
        return next
    except:
        next = browser.find_element_by_xpath("//a[contains(text(),'Siguiente')]")
        browser.implicitly_wait(1)
        return next

def fecha_2020(fecha):
    fecha2020=fecha[:4]
    if fecha2020=="2020":
        return True
    return False

def quitar_enter(linea):
    texto=""
    palabras=linea.split("\n")
    for pal in palabras:
        texto=texto.strip()+" "+pal.strip()
    return texto

browser=webdriver.Chrome("C:\chromedriver.exe")
browser.get(url)
time.sleep(1)
login(username, password)

#cerrar ventana emergente
time.sleep(1)
windows= browser.find_element_by_xpath("/html/body/div[4]/div/div/div[3]/button[2]")
windows.click()
# browser.maximize_window()
# #Buscar por provincias
#
# for provin in provincias:
#     buscar_por_provincia=browser.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
#     browser.implicitly_wait(10)
#     buscar_por_provincia.send_keys(provin+" "+"Provinc")
#     time.sleep(10)
#     buscar_por_provincia.send_keys(Keys.ENTER)
#     buscar_por_provincia.send_keys(Keys.ENTER)
#     time.sleep(10)
#     first_picture()
#     browser.implicitly_wait(10)
#
# # Post por provincia
#
#     i = 0
#     while True:
#         i = i + 1
#         name = browser.find_element_by_class_name("e1e1d")
#         browser.implicitly_wait(10)
#         nombre_usuario = name.text
#         nombre_usuario = nombre_usuario.strip("Verified\n")
#         link = name.find_element_by_tag_name("a").get_attribute("href")
#         browser.implicitly_wait(10)
#         ubicacion = browser.find_element_by_class_name("JF9hh")
#         browser.implicitly_wait(10)
#         if ubicacion.text != "":
#             browser.implicitly_wait(10)
#             ubicacion = browser.find_element_by_class_name("JF9hh").text
#             ubicacion=ubicacion.replace(",", "")
#             browser.implicitly_wait(10)
#         else:
#             ubicacion = ""
#         descripcion = browser.find_element_by_class_name("EtaWk").text
#         browser.implicitly_wait(10)
#         if descripcion != "":
#             descripcion = browser.find_element_by_class_name("C4VMK")
#             browser.implicitly_wait(10)
#             descripcion = descripcion.text
#             if nombre_usuario in descripcion:
#                 descripcion = descripcion.strip(nombre_usuario + "Verified\n")
#                 browser.implicitly_wait(10)
#                 try:
#                     tiempo = browser.find_element_by_xpath("/html/body/div[4]/div[2]/div/article/div[2]/div[1]/ul/div/li/div/div/div[2]/div/div/time").text
#                     browser.implicitly_wait(10)
#                     descripcion = descripcion.strip(tiempo + "\n")
#                     descripcion = quitar_enter(descripcion)
#                     descripcion = descripcion.replace("|", "")
#                     descripcion = descripcion.replace(",", "")
#                 except:
#                     tiempo = browser.find_element_by_xpath("/html/body/div[4]/div[2]/div/article/div[2]/div[1]/ul/ul[1]/div/li/div/div[1]/div[2]/div/div/a/time").text
#                     browser.implicitly_wait(10)
#                     descripcion = descripcion.strip(tiempo + "\n")
#                     descripcion = quitar_enter(descripcion)
#                     descripcion = descripcion.replace("|", "")
#                     descripcion = descripcion.replace(",", "")
#             else:
#                 descripcion = ""
#         else:
#             descripcion = ""
#         datetime = browser.find_element_by_class_name("c-Yi7").find_element_by_tag_name("time").get_attribute("datetime")
#         browser.implicitly_wait(10)
#         datetime = datetime.split("T")
#         fecha = datetime[0]
#         hora = datetime[1][:8]
#         if fecha_2020(fecha) == False:
#             break
#         else:
#             datos_usuario_provincia = provin + '|' + nombre_usuario + '|' + ubicacion + '|' + fecha + '|' + hora +'|'+ descripcion + "\n"
#             archivo_de_publicaciones_por_provincias.write(datos_usuario_provincia)
#             archivo_de_publicaciones_por_perfil.write(provin + '|' + nombre_usuario + '|' + link + "\n")
#             print(datos_usuario_provincia)
#             try:
#                 next_picture().click()
#                 browser.implicitly_wait(10)
#             except:
#                 break
#
# archivo_de_publicaciones_por_provincias.close()
# archivo_de_publicaciones_por_perfil.close()

#Post por perfil

archivo_de_publicaciones_por_provincias_perfil= open("Santa_Elena_1.csv", "w",newline='' ,encoding='utf-8-SIG')
encabezado1=["Provincia","Nombre de usuario","Publicaciones","Seguidores","Seguidos","Descripcion del perfil","Lugar","Fecha","Hora","Descripcion del post"]
salida= csv.writer(archivo_de_publicaciones_por_provincias_perfil,delimiter='|')
salida.writerow(encabezado1)


csvarchivo = open('Publicaciones_por_perfil_Santa_Elena.csv')  # Abrir archivo csv
 'nahomi_veroes', 'luis_enrique0407', '360banda', 'aniela_gonzalez08', 'karellys', 'chef_cito_', 'genaty22', '.uniforms.ec', 'carlosreyesnegret', 'paperartgy', 'vipcreativo', 'benjamin.guaman', 'mishelle.s', 'aniel_fajardo11', 'odcontast', 'mariabelenlopezleon', 'sembradoresdevida_oficial', 'alejandro.toroc', 'lanz_spac', 'ayanarasornoza25', 'laela.ec', 'yu_dentalkids', 'chechi_ec', 'npa_fashion_17', 'vettemoncada22', 'mayer.makeup2020', 'nesto', 'biopinasec', 'mayra10238', 'gerardo0783', 'luminatech.studio', 'geocordova1', 'oberth_eventos_show_', 'johannmenendez', 'jesusfotografiayvideo', 'ce_villegas90', 'spinosagarden', 'studiodesign.ec', 'a.campov', 'aespecial.ec', 'mecauto_express', 'pilier.gy', 'arreglosdedulcesmay', 'animalart.akiv', 'k_per84', 'andynatyjaramillo', 'nicolasperibonio', 'wachitobajana_1983', 'marlon96am', 'nazambrano193', 'ninjas_yisus', 'stebanbaez3', 'private.event_gy', 'kaisy_makeup98', 'adri_saavedra93', 'modachic_bisuteria', 'bylilo.ec', 'xav', 'alcivar_cujilan', 'sophideasparafiestas', 'tsthorlov', 'alilagonzam', 'larr_motors', 'pyc_ec', 'greciavillaro', 'cokrisbarzo', 'beautyworld_ec', 'kachoez714', 'labandaandres', 'tiendas_shoes', 'shine_moonec', 'wi_technology', 'menacemorales', 'megabike_sto', 'bmxguayas', 'karlacabarico', 'betsabefalcones', 'susanskinbeauty', 'nandomarmolp', 'tiendalumerc', 'anapaulaalmendariz', 'canelitalojan', 'jcandca', 'herfersbakery', 'miguelhoyosvera', 'super_novedades_alexa', 'glen.tigua', 'sakruizy', 'lookwithcris', 'pablonerijimen', 'seba_s593', 'lapolleria54', 'cristym1992', 'c12sport', 'sforcia_hoga', 'asycocpsa', 'canizares1973', 'mariuxiballen', 'mundusmem', 'shopbyginacevallos', 'lajaulafutbol', 'solochicasplus', '_barbaran', 'kerlyalvaradojoyas', 'lacuerdaacusticaoficial', 'punto_fri0', 'bebecita_liss', 'hilos_de_oro', 'virgixhelp', 'berthacabreramunoz', 'chulisforever_ec', 'loky_n_thanos', 'apecedoblev', 'conectapack', 'studiodayrazambrano', 'albertomedinacarlos', 'adriifit_11', 'barchimakeup', 'velasquezfotografia', 'nexumcorp_ec', 'jagm1406', 'kioskitos_express', 'kemichoc', 'sellvickyy', 'cuaproductos', 'jonelvicmposs', 'holasoyrosiita', 'karellhairmakeup', 'osetvillasagua', 'jhonylucasbq', 'meredith_franco_01', 'kudos_realty', 'kp_eventos', 'kp_antojitos_express', 'kpsublime.ec', 'texts_quotes_dx', 'maykoljapson', 'climatekecuado', 'ag.centro.de.sonrisas', 'biancagalarza_', 'stetica_microbladinga', 'nfanciasomostodos', 'suitcase_usa', 'thekitchen_workshop', 'mishiikka', 'krystelhermidawing', 'beto_alexan', 'umonasterio', 'avisdizza', 'liciascreativas_ec', 'mariajosesantanan', 'macys_cakes', 'udrgy', 'buybuy_ec', 'oxdecuado', 'mojitos593', 'here_banz', 'lachicapremium', 'adry18jordanm', 'herepresentaciones', 'marthykbb', 'costacleanec', 'vinascosta', 'natoholguin', 'hellen.munozc', 'smart_tecnology_guayaquil', 'bryan_josuegarca', 'nternetfibraopticaecuado', 'lefantyec', 'kendyjosec', 'pereiramua', 'jesmavillacreses', 'jeff_macias90', 'stony.ec', 'anrivzam', 'astwash.gy', 'titomoran15', 'thalia_rivadeneira', 'lisabel_carvajal', 'capacitacioneslopmu', 'aranduleroecu', 'hectorluismontes', 'yuliixa97', 'karenannaya_', 'creaciones_mia_s', 'vetourecuado', 'chrisholguin21', 'loris_little_princess', 'larystoffers', '_ldmm77', 'stalynpazmino', 'ayiicm31', 'ucational_solutions', 'tedivina_gy', 'mprendeyadelgazaconroyramirez', 'jonathanjbaez', 'ayana_1618', 'veronicacordero', 'avidvallesalsa', 'kdrops_plus23', 'nutribusiness2018', 'kdropsecuador3', 'carlos.macias.9210256', 'chicgirls.ecu', 'ade_9709', 'bartolomeacu_a', 'campotrack_', 'oal_excavato', 'andrea_fiallo', 'jesseglamshoetiqu', 'henryfierro', 'brunita.ec', 'cristhianborja200', 'beikebrito12', 'l_canango593', 'paulet.andra', 'casadelagoeventos', 'anasanchezdelvalle1994', 'gna.pinela', 'stephanie_noe24', 'justingutierrez142', 'carlosozoranga', 'upoops', 'viajerosec_', 'piyahuaje_elkin', 'nvitacionesec', 'briggitte362', 'yuyoph', 'tendencyshop.ec', 'pmazzey_photo', 'chriscalicc', '_livesa', 'pachacuidatusalu', 'candyque_sol', 'ponchoquintero1', 'joseantoniov54', 'lrincondelsantero', 'cardenasgelo', 'carneros.ec', 'asymall.ec', 'velzamcleaning', 'mmitastorec', 'zaruma', 'avid_nav7', 'ponte_de_moda21', 'yelimar19avila', 'patricialilianaruiz', 'kakuro', 'gosaltos33', 'co_empresas', 'calliebudz', 'bampe_shoes', 'angelemmanuel88', 'lineacypress', 'psicologoandresibarraleon', 'vetteeecm', 'kattymelgartv', 'linaveg', 'pabloredinvidal', 'cuadortravel', 'kathapincay', 'leandro_tutiven_95', 'leyner__sanchez', 'tienda305', 'perlajadima', 'arqingtec', 'carolinachangmakeup', 'sweet_details_of_love.ec', 'anielsanteoficial', 'umaroficial', 'angie_la_div', 'perritos_gatitos_adorables', 'osiencalada', 'cardo.teran', 'cristhoperchiliquinga', 'alframe.leyda', 'aviobarb', 'colamarcogeovannygalarza', 'chrizzico', 'modeldanc', '__yeyo___', 'asprec_ec', 'luchorondon_vip', 'heidyj', 'ceviches_elautentico', 'paolabenalcazar39']
for line in entrada:
#   print(usu_re)
  time.sleep(7)
  line="".join(line)
  provincia,usuario,link=line.split("|")
  a=a+1
  if a==1 :
      continue

  if usuario in usu_re:
      continue

  usu_re.append(usuario)
  browser.get(link)
  time.sleep(2)
  if first_picture() == False:
      continue
  try:
      browser.implicitly_wait(1)
      browser.find_element_by_xpath("/html/body/div/div[1]/div/div/h2").text=="Sorry, this page isn't available."
      continue
  except:
      browser.implicitly_wait(1)
      descripcion_perfil=browser.find_element_by_class_name("-vDIg").text
      browser.implicitly_wait(1.5)
      descripcion_perfil=quitar_enter(descripcion_perfil)
      descripcion_perfil=descripcion_perfil.replace("|", "")
      descripcion_perfil=descripcion_perfil.replace(",", "")
      descripcion_perfil=descripcion_perfil.replace('"', "")
      usu=link[26:-1]
      browser.implicitly_wait(1)
      d_publicados=browser.find_elements_by_class_name("-nal3 ")
      lista = []
      for elem in d_publicados:
          browser.implicitly_wait(1)
          elem = elem.find_element_by_class_name("g47SY ").text
          lista.append(elem)
#       print(lista)
      if lista[0]=="" and lista[1]==""  and lista[2]=="":
          r=requests.get(link)
          meta=BeautifulSoup(r.text, "html.parser")
          meta = meta.find("meta", property="og:description")
          d_publicados=meta.attrs['content']
          browser.implicitly_wait(1)
          d_publicados=d_publicados.split("-")
          d_publicad=d_publicados[0].strip().split(" ")
          if d_publicad[4].isalpha() or  d_publicad[0].isalpha() or d_publicad[2].isalpha():
              lista=["","",""]
              lista = "|".join(lista)
          else:
              lista="{} posts|{} followers|{} following".format(d_publicad[4],d_publicad[0],d_publicad[2])
      # d_publicados=browser.find_elements_by_class_name("-nal3 ")
      # browser.implicitly_wait(10)
      # for elem in d_publicados:
      #     elem=elem.find_element_by_tag_name('span').text
      #     lista.append(elem)
      # if lista[0]=="" and lista[1]==""  and lista[2]=="":
          # posts = WebDriverWait(browser, 5).until(EC.presence_of_element_located((By.XPATH, '//li/span[text()=" posts"]/span'))).text
          # followers = WebDriverWait(browser, 5).until(EC.presence_of_element_located((By.XPATH, '//li/a[text()=" followers"]/span'))).text
          # following = WebDriverWait(browser, 5).until(EC.presence_of_element_located((By.XPATH, '//li/a[text()=" following"]/span'))).text
          # lista="{} posts | {} followers | {} following".format(posts, followers, following)
      #
          # lista = []
          # post = browser.find_element_by_xpath("/html/body/div[1]/section/main/div/header/section/ul/li[1]/span/span").text
          # browser.implicitly_wait(10)
          # lista.append(post)
          # followers = browser.find_element_by_xpath("/html/body/div[1]/section/main/div/header/section/ul/li[2]/a/span").text
          # browser.implicitly_wait(10)
          # lista.append(followers)
          # following = browser.find_element_by_xpath("/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span").text
          # browser.implicitly_wait(10)
          # lista.append(following)
      else:
          lista[0] = lista[0] + " " + "posts"
          lista[1] = lista[1] + " " + "followers"
          lista[2] = lista[2] + " " + "following"
          lista = "|".join(lista)
      lista = lista.replace(",", ".")
      provincia=provincia.replace("Ã‘","Ñ")
      datos= provincia+'|'+usu+'|'+lista+'|'+descripcion_perfil
      time.sleep(1)
      i=0
      while True:
          i=i+1
          browser.implicitly_wait(2)
          name = browser.find_element_by_class_name("e1e1d")
          browser.implicitly_wait(2)
          nombre_usuario = name.text
          nombre_usuario = nombre_usuario.strip("Verified\n")
          browser.implicitly_wait(2)
          ubicacion = browser.find_element_by_class_name("JF9hh")
          browser.implicitly_wait(2)
          if ubicacion.text != "":
              browser.implicitly_wait(2)
              ubicacion = browser.find_element_by_class_name("JF9hh").text
              browser.implicitly_wait(2)
              ubicacion=ubicacion.replace(",", "")
          else:
              ubicacion = ""
          descripcion = browser.find_element_by_class_name("EtaWk").text
          browser.implicitly_wait(1)
          if descripcion != "":
              descripcion = browser.find_element_by_class_name("C4VMK")
              browser.implicitly_wait(1)
              descripcion = descripcion.text
              if nombre_usuario in descripcion:
                  descripcion = descripcion.strip(nombre_usuario + "Verified\n")
                  browser.implicitly_wait(1)
                  try:
                      tiempo = browser.find_element_by_xpath("/html/body/div[4]/div[2]/div/article/div[2]/div[1]/ul/div/li/div/div/div[2]/div/div/time").text
                      browser.implicitly_wait(1)
                      descripcion = descripcion.strip(tiempo + "\n")
                      descripcion = quitar_enter(descripcion)
                      descripcion = descripcion.replace("|", "")
                      descripcion = descripcion.replace(",", "")
                      descripcion = descripcion.replace('"', "")

                  except :
                      tiempo = browser.find_element_by_xpath("/html/body/div[4]/div[2]/div/article/div[2]/div[1]/ul/ul/div/li/div/div[1]/div[2]/div/div/a/time").text
                      browser.implicitly_wait(1)
                      descripcion = descripcion.strip(tiempo + "\n")
                      descripcion = quitar_enter(descripcion)
                      descripcion = descripcion.replace("|", "")
                      descripcion = descripcion.replace(",", "")
                      descripcion = descripcion.replace('"', "")


              else:
                  descripcion = ""
          else:
              descripcion = ""
          datetime = browser.find_element_by_class_name("c-Yi7").find_element_by_tag_name("time").get_attribute("datetime")
          browser.implicitly_wait(1)
          datetime = datetime.split("T")
          fecha = datetime[0]
          hora = datetime[1][:8]
          if fecha_2020(fecha) == False :
              break
          else:
              datos_usuario_provincia = datos + '|' + ubicacion + '|' + fecha + '|' + hora + '|' + descripcion +  "\n"
              archivo_de_publicaciones_por_provincias_perfil.write(datos_usuario_provincia)
              print(datos_usuario_provincia)
              try:
                  next_picture().click()
                  time.sleep(1)
              except:
                  break 
browser.close()
archivo_de_publicaciones_por_provincias_perfil.close()
csvarchivo.close()
# Out:
# SANTA ELENA|ruidito|335 posts|27.7k followers|1.971 following|Arita 🦋 DJ fashion stylist @cukicastello 📍🇦🇷|En Casita|2020-05-03|09:10:44|me quedo con esta placa de la noche de hoy 💘 @fiestabresh una vez más haciendo historia y hablemos por favor de cómo la rompió @pablomonky ídolo total te amamos. los looks son siempre hermosos porque es el laburo de @cukicastello feat @veropacheco__ 〰️
#
# SANTA ELENA|ruidito|335 posts|27.7k followers|1.971 following|Arita 🦋 DJ fashion stylist @cukicastello 📍🇦🇷||2020-05-01|21:11:47| @aynotdead 🕷
#
# SANTA ELENA|ruidito|335 posts|27.7k followers|1.971 following|Arita 🦋 DJ fashion stylist @cukicastello 📍🇦🇷||2020-04-30|15:55:14| @aynotdead 🌼
#
# ...
